# %%
import os
from google.colab import userdata

PAT = userdata.get('GH_PAT')
REPO = 'Melodiz/tmp-hachaton'

if not os.path.exists('/content/hackathon'):
    os.system(f'git clone https://{PAT}@github.com/{REPO}.git /content/hackathon')
    print('Cloned.')
else:
    print('Already cloned. Use Cell 3 to pull.')
# Out:
# Cloned.

# %%
os.system('pip install -q -r /content/hackathon/requirements.txt')
print('Installed.')
# Out:
# Installed.

# %%
os.system('cd /content/hackathon && git pull')
print('Pulled.')
# Out:
# Pulled.

# %%
# !cd /content/hackathon && python train.py --cfg cfg.yaml
# Out:
# device=cuda
# 100% 170M/170M [00:04<00:00, 42.0MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /content/hackathon/train.py:24: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# ...

# %%
os.system('cd /content/hackathon && python infer.py --cfg cfg.yaml')
# Out:
# 0

# %%
from google.colab import files
files.download('/content/hackathon/submission.csv')
